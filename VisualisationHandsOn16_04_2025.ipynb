# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/cars.csv',skipinitialspace=True)
df
# Out:
#       mpg  cylinders  cubicinches   hp  weightlbs  time-to-60  year    brand
# 0    14.0          8        350.0  165     4209.0          12  1972      US.
# 1    31.9          4         89.0   71     1925.0          14  1980  Europe.
# 2    17.0          8        302.0  140     3449.0          11  1971      US.
# 3    15.0          8        400.0  150     3761.0          10  1971      US.
# 4    30.5          4         98.0   63     2051.0          17  1978      US.
# ..    ...        ...          ...  ...        ...         ...   ...      ...
# 256  17.0          8        305.0  130     3840.0          15  1980      US.
# 257  36.1          4         91.0   60     1800.0          16  1979   Japan.
# 258  22.0          6        232.0  112     2835.0          15  1983      US.
# 259  18.0          6        232.0  100     3288.0          16  1972      US.
# 260  22.0          6        250.0  105     3353.0          15  1977      US.
#
# [261 rows x 8 columns]

# %% [markdown]
# **Check for null values and duplicate values in the data, get the basic information about the dataset**

# %%
df.isnull().sum()
# Out:
# mpg            0
# cylinders      0
# cubicinches    2
# hp             0
# weightlbs      3
# time-to-60     0
# year           0
# brand          0
# dtype: int64

# %%
df.dropna(inplace=True)   # dropna is used to remove null values from our dataset.

# %%
df.isnull().sum()
# Out:
# mpg            0
# cylinders      0
# cubicinches    0
# hp             0
# weightlbs      0
# time-to-60     0
# year           0
# brand          0
# dtype: int64

# %%
df.duplicated().sum()
# df.drop_duplicates(inplace=True) Used to delete duplicate rows.
# Out:
# np.int64(0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 256 entries, 0 to 260
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   mpg          256 non-null    float64
#  1   cylinders    256 non-null    int64
#  2   cubicinches  256 non-null    float64
#  3   hp           256 non-null    int64
#  4   weightlbs    256 non-null    float64
#  5   time-to-60   256 non-null    int64
#  6   year         256 non-null    int64
#  7   brand        256 non-null    object
# dtypes: float64(3), int64(4), object(1)
# memory usage: 18.0+ KB

# %% [markdown]
# **Create scatter plots for the following columns**
#
# 1.   mpg-hp
# 2.   mpg-weight
# 3.   hp-mpg
# 4.   hp-time-to-60
# **with respect to each brand. Make sure all the plots appear in the same plane with x-labels and y-labels evenly spaced.**

# %%
plt.scatter(df['mpg'],df['hp'])
plt.xlabel('Miles Per Gallon')
plt.ylabel('Horse Power')
plt.title('MPG V/S HP')
plt.show()

# %%
sns.scatterplot(x=df['mpg'],y=df['hp'],hue=df['brand']) # Hue parameter gives different colors to data point with respect to column.
plt.xlabel('Miles Per Gallon')
plt.ylabel('Horse Power')
plt.title('MPG V/S HP')
plt.show()

# %%
fig = plt.subplots(2,2,figsize=(20,10))

plt.subplot(2,2,1)
sns.scatterplot(x=df['mpg'],y=df['hp'],hue=df['brand'])
plt.xlabel('Miles Per Gallon')
plt.ylabel('Horse Power')
plt.title('MPG V/S HP')

plt.subplot(2,2,2)
sns.scatterplot(x=df['mpg'],y=df['weightlbs'],hue=df['brand'])
plt.xlabel('Miles Per Gallon')
plt.ylabel('Weight LBS')
plt.title('MPG V/S WeightLBS')

plt.subplot(2,2,3)
sns.scatterplot(x=df['hp'],y=df['mpg'],hue=df['brand'])
plt.xlabel('Horse Power')
plt.ylabel('Miles Per Gallon')
plt.title('HP V/S MPG')

plt.subplot(2,2,4)
sns.scatterplot(x=df['hp'],y=df['time-to-60'],hue=df['brand'])
plt.xlabel('Horse Power')
plt.ylabel('Time to 60')
plt.title('HP V/S Time_to_60')

plt.show()

# %% [markdown]
# **Create bar plots for the following columns:**
#
#
# 1.   cylinders-hp
# 2.   cylinders-mpg
# 3.   cylinders-weight-
# 4.   cylinders-time-to-60
# **Make sure all the plots appear in the same plane with x-labels and y-labels evenly spaced.**

# %%
fig = plt.subplots(2,2,figsize=(18,12))

plt.subplot(2,2,1)
sns.barplot(x=df['cylinders'],y=df['hp'],hue=df['brand'])
plt.xlabel('Cylinders')
plt.ylabel('Horse Power')
plt.title('Cylinders V/S Horse Power')

plt.subplot(2,2,2)
sns.barplot(x=df['cylinders'],y=df['mpg'],hue=df['brand'])
plt.xlabel('Cylinders')
plt.ylabel('Miles Per Gallon')
plt.title('Cylinders V/S MPG')

plt.subplot(2,2,3)
sns.barplot(x=df['cylinders'],y=df['weightlbs'],hue=df['brand'])
plt.xlabel('Cylinders')
plt.ylabel('WeightLBS')
plt.title('Cylinders V/S WeightLBS')

plt.subplot(2,2,4)
sns.barplot(x=df['cylinders'],y=df['time-to-60'],hue=df['brand'])
plt.xlabel('Cylinders')
plt.ylabel('time-to-60')
plt.title('Cylinders V/S time-to-60')

plt.show()

# %% [markdown]
# **Create a pair plot for the entire data to study various patterns in our dataset.**

# %%
sns.pairplot(df,hue='brand')

# %%
# Create a pie chart for brand column.
df['brand']
# Out:
# 0          US.
# 1      Europe.
# 2          US.
# 3          US.
# 4          US.
#         ...
# 256        US.
# 257     Japan.
# 258        US.
# 259        US.
# 260        US.
# Name: brand, Length: 256, dtype: object

# %%
x = df['brand'].value_counts()

# %%
x
# Out:
# brand
# US.        158
# Japan.      51
# Europe.     47
# Name: count, dtype: int64

# %%
x.plot.pie()
plt.show()

# %%
x.plot.pie(autopct="%.2f%%")
plt.show()

# %% [markdown]
# 1.Create a heatmap for this data
#
# 2.Create a histogram for the following columns:
#
# 3.hp , mpg , time-to-60, weightlbs, cubic inches, year , cylinders with respect to brand
