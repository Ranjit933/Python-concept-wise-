# %% [markdown]
# ### **Importing the required packages**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, roc_auc_score, precision_score, recall_score, f1_score

# %% [markdown]
# ### **Reading and Exploring the Data**

# %%
data = pd.read_csv('creditcard.csv')

# %%
data.head()
# Out:
#          V1        V2        V3        V4  ...       V27       V28    V29  Target
# 0  0.114697  0.796303 -0.149553 -0.823011  ...  0.242724  0.085713   0.89       0
# 1 -0.039318  0.495784 -0.810884  0.546693  ...  0.113136  0.256836  85.00       0
# 2  2.275706 -1.531508 -1.021969 -1.602152  ...  0.014197 -0.051289  42.70       0
# 3  1.940137 -0.357671 -1.210551  0.382523  ... -0.012791 -0.056841  29.99       0
# 4  1.081395 -0.502615  1.075887 -0.543359  ...  0.089673  0.052036  68.00       0
#
# [5 rows x 30 columns]

# %%
data.shape
# Out:
# (56962, 30)

# %%
data.isnull().sum()
# Out:
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# V29       0
# Target    0
# dtype: int64

# %%
data.duplicated().sum() #print the total number of duplicate rows in our data
# Out:
# np.int64(675)

# %%
data[data.duplicated()] #print all the duplicate rows
# Out:
#              V1        V2        V3  ...       V28    V29  Target
# 1181   2.010213  0.063667 -1.620606  ... -0.040558   1.79       0
# 1936   1.302378 -0.606529 -0.681986  ...  0.028697   1.00       0
# 2530   2.055797 -0.326668 -2.752041  ... -0.060282   1.00       0
# 2878   1.076018 -0.126284  1.320255  ...  0.024214   1.00       0
# 3301   1.109985  0.368032 -0.061407  ...  0.020956  89.99       0
# ...         ...       ...       ...  ...       ...    ...     ...
# 56809  1.886717 -0.517305 -1.351317  ... -0.081462  20.00       0
# 56830  1.284143  0.462738 -0.371277  ... -0.005489   0.89       0
# 56865  1.018412  1.036663 -1.689814  ...  0.071818   0.89       0
# 56893  2.060160  0.018599 -1.072853  ... -0.058989   1.29       0
# 56939 -1.807896  1.155051  0.272890  ...  0.131012   6.14       0
#
# [675 rows x 30 columns]

# %%
data.drop_duplicates(inplace = True)  #remove all the duplicate rows

# %%
#check for data imbalance in classification
data['Target'].value_counts()
# Out:
# Target
# 0    56189
# 1       98
# Name: count, dtype: int64

# %%
56189 / 56287
# Out:
# 0.9982589230195249

# %%
98 / 56287
# Out:
# 0.0017410769804750653

# %% [markdown]
# ### **To do for imbalanced data**:
#
# 1. Oversampling (SMOTE).
# 2. Undersampling (RandomUnderSampler).
# 3. Use Tree Based Algortihms.

# %% [markdown]
# ### **Machine Learning Process**

# %%
X = data.drop(columns = ['Target'])
y = data['Target']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, stratify = y, random_state = 10000)

# %% [markdown]
# #### **Apply Random Forest Classifier on the data**

# %%
rfc = RandomForestClassifier()
rfc.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred = rfc.predict(X_test)

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.9991117427607035

# %% [markdown]
# #### Note : Never use accuracy_score in the case of imbalanced data. Use roc_auc_score instead.

# %%
roc_auc_score(y_test, y_pred)
# Out:
# np.float64(0.7999110161950526)

# %%
from sklearn.metrics import confusion_matrix

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[11236,     2],
#        [    8,    12]])

# %%
cm = confusion_matrix(y_test, y_pred)

# %%
TN, FP, FN, TP = cm.ravel()

# %%
print(TN, TP, FN, FP)
# Out:
# 11236 12 8 2

# %%
precision_score(y_test, y_pred)
# Out:
# 0.8571428571428571

# %%
recall_score(y_test, y_pred)
# Out:
# 0.6
