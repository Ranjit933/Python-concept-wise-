# %% [markdown]
# **Dataset URL:**https://drive.google.com/file/d/1GAWxYVsxykgZ-7jk2X_MQRSeFRy3aH0Z/view?usp=drive_link
#
#
# **PPT LINK:** https://drive.google.com/file/d/1kCt53fxG1Opfd2BgLeePJpCqev3eooaj/view?usp=drive_link

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/BBData (1).csv')
df
# Out:
#        index                                            product  \
# 0          1             Garlic Oil - Vegetarian Capsule 500 mg
# 1          2                              Water Bottle - Orange
# 2          3                     Brass Angle Deep - Plain, No.2
# 3          4  Cereal Flip Lid Container/Storage Jar - Assort...
# 4          5                 Creme Soft Soap - For Hands & Body
# ...      ...                                                ...
# 27550  27551         Wottagirl! Perfume Spray - Heaven, Classic
# 27551  27552                                           Rosemary
# 27552  27553                       Peri-Peri Sweet Potato Chips
# 27553  27554                          Green Tea - Pure Original
# 27554  27555                     United Dreams Go Far Deodorant
#
#                      category              sub_category  \
# 0            Beauty & Hygiene                 Hair Care
# 1      Kitchen, Garden & Pets     Storage & Accessories
# ...

# %%
# Number of Unique Categories of Products
# Fetch the top categories
# Fetch the least categories
# Average sale and average market price



#Max discounted item is Premium Cloth Dryer/Drying Stand - Foldable
#and the discounted amount is 4320 and sale price 4649 and MRP is 8969.

# Find out all the products where sale price and market price is same.

# %%
# Number of Unique Categories of Products

df['category'].unique()
# Out:
# array(['Beauty & Hygiene', 'Kitchen, Garden & Pets',
#        'Cleaning & Household', 'Gourmet & World Food',
#        'Foodgrains, Oil & Masala', 'Snacks & Branded Foods', 'Beverages',
#        'Bakery, Cakes & Dairy', 'Baby Care', 'Fruits & Vegetables',
#        'Eggs, Meat & Fish'], dtype=object)

# %%
# Fetch the top categories

top_categories = df['category'].value_counts().head(10)
top_categories
# Top Category: Beauty & Hygience
# Least Category: Eggs, Meat & Fish
# Out:
# category
# Beauty & Hygiene            7867
# Gourmet & World Food        4690
# Kitchen, Garden & Pets      3580
# Snacks & Branded Foods      2814
# Foodgrains, Oil & Masala    2676
# Cleaning & Household        2675
# Beverages                    885
# Bakery, Cakes & Dairy        851
# Baby Care                    610
# Fruits & Vegetables          557
# Name: count, dtype: int64

# %%
top_categories.plot(kind='barh', figsize=(10,6), color='skyblue')
plt.xlabel('Number of Products')
plt.ylabel('Category')
plt.title('Top Product Categories')
plt.gca().invert_yaxis()
plt.tight_layout()
plt.show()

# %%
# Average sale and average market price

print(df['sale_price'].mean())
print(df['market_price'].mean())
# Out:
# 322.5148078388677
# 382.05666448920346

# %%
#Max discounted item is Premium Cloth Dryer/Drying Stand - Foldable
#and the discounted amount is 4320 and sale price 4649 and MRP is 8969.

df['Discount'] = df['market_price'] - df['sale_price']

# %%
df.sort_values(by='Discount',ascending=False)
# Out:
#        index                                            product  \
# 21930  21931  Premium Cloth Dryer/Drying Stand - Foldable, S...
# 23082  23083  Gas Stove-4 Burner Royale Plus Schott Glass, B...
# 1056    1057  Gas Stove-3 Burner Royale Plus Schott Glass, B...
# 2343    2344  Induction Base Non Stick Cookware Set With Gla...
# 8759    8760  Dinner Set - Laser Etched, Premium Stainless S...
# ...      ...                                                ...
# 18996  18997                      Namkeen - Low Fat Makai Papdi
# 18994  18995                         Alaska Glass Bowl With Lid
# 18992  18993               Room Freshening Gelz - Passion Fruit
# 18991  18992                   Incense Sticks - Breezy Lavender
# 3847    3848                                       HimCal - Pet
#
#                      category             sub_category               brand  \
# 21930  Kitchen, Garden & Pets    Storage & Accessories                  DP
# ...

# %%
# Find out all the products where sale price and market price is same.

df[df['sale_price'] == df['market_price']]
# Out:
#        index                                    product  \
# 0          1     Garlic Oil - Vegetarian Capsule 500 mg
# 1          2                      Water Bottle - Orange
# 4          5         Creme Soft Soap - For Hands & Body
# 6          7                               Multani Mati
# 7          8          Hand Sanitizer - 70% Alcohol Base
# ...      ...                                        ...
# 27541  27542  Herbal Rose & Apricot Walnut Facial Scrub
# 27547  27548                            Powder - Baking
# 27548  27549                Apple Cider Vinegar Shampoo
# 27549  27550                       Papad - Garlic Disco
# 27552  27553               Peri-Peri Sweet Potato Chips
#
#                      category              sub_category              brand  \
# 0            Beauty & Hygiene                 Hair Care  Sri Sri Ayurveda
# 1      Kitchen, Garden & Pets     Storage & Accessories         Mastercook
# ...

# %%
df[df['Discount']==0]  #Another Approach
# Out:
#        index                                    product  \
# 0          1     Garlic Oil - Vegetarian Capsule 500 mg
# 1          2                      Water Bottle - Orange
# 4          5         Creme Soft Soap - For Hands & Body
# 6          7                               Multani Mati
# 7          8          Hand Sanitizer - 70% Alcohol Base
# ...      ...                                        ...
# 27541  27542  Herbal Rose & Apricot Walnut Facial Scrub
# 27547  27548                            Powder - Baking
# 27548  27549                Apple Cider Vinegar Shampoo
# 27549  27550                       Papad - Garlic Disco
# 27552  27553               Peri-Peri Sweet Potato Chips
#
#                      category              sub_category              brand  \
# 0            Beauty & Hygiene                 Hair Care  Sri Sri Ayurveda
# 1      Kitchen, Garden & Pets     Storage & Accessories         Mastercook
# ...

# %%
df[df['Discount']==0]
# Out:
#        index                                    product  \
# 0          1     Garlic Oil - Vegetarian Capsule 500 mg
# 1          2                      Water Bottle - Orange
# 4          5         Creme Soft Soap - For Hands & Body
# 6          7                               Multani Mati
# 7          8          Hand Sanitizer - 70% Alcohol Base
# ...      ...                                        ...
# 27541  27542  Herbal Rose & Apricot Walnut Facial Scrub
# 27547  27548                            Powder - Baking
# 27548  27549                Apple Cider Vinegar Shampoo
# 27549  27550                       Papad - Garlic Disco
# 27552  27553               Peri-Peri Sweet Potato Chips
#
#                      category              sub_category              brand  \
# 0            Beauty & Hygiene                 Hair Care  Sri Sri Ayurveda
# 1      Kitchen, Garden & Pets     Storage & Accessories         Mastercook
# ...

# %%
# pd.reset_option('display.max_colwidth')

# %%
# pd.set_option('display.max_colwidth',None)
# df['description']

# %%
# Homework:
# Get Valuable insights from this dataset and if possible build a model
df['description'].value_counts()
# Out:
# description
# ...

# %%
df
# Out:
#        index                                            product  \
# 0          1             Garlic Oil - Vegetarian Capsule 500 mg
# 1          2                              Water Bottle - Orange
# 2          3                     Brass Angle Deep - Plain, No.2
# 3          4  Cereal Flip Lid Container/Storage Jar - Assort...
# 4          5                 Creme Soft Soap - For Hands & Body
# ...      ...                                                ...
# 27550  27551         Wottagirl! Perfume Spray - Heaven, Classic
# 27551  27552                                           Rosemary
# 27552  27553                       Peri-Peri Sweet Potato Chips
# 27553  27554                          Green Tea - Pure Original
# 27554  27555                     United Dreams Go Far Deodorant
#
#                      category              sub_category  \
# 0            Beauty & Hygiene                 Hair Care
# 1      Kitchen, Garden & Pets     Storage & Accessories
# ...

# %%
df
# Out:
#        index                                            product  \
# 0          1             Garlic Oil - Vegetarian Capsule 500 mg
# 1          2                              Water Bottle - Orange
# 2          3                     Brass Angle Deep - Plain, No.2
# 3          4  Cereal Flip Lid Container/Storage Jar - Assort...
# 4          5                 Creme Soft Soap - For Hands & Body
# ...      ...                                                ...
# 27550  27551         Wottagirl! Perfume Spray - Heaven, Classic
# 27551  27552                                           Rosemary
# 27552  27553                       Peri-Peri Sweet Potato Chips
# 27553  27554                          Green Tea - Pure Original
# 27554  27555                     United Dreams Go Far Deodorant
#
#                      category              sub_category  \
# 0            Beauty & Hygiene                 Hair Care
# 1      Kitchen, Garden & Pets     Storage & Accessories
# ...

# %%
df.isnull().sum()
# Out:
# index              0
# product            1
# category           0
# sub_category       0
# brand              1
# sale_price         0
# market_price       0
# type               0
# rating          8626
# description      115
# Discount           0
# dtype: int64

# %%
df['description'] = df['description'].replace(np.nan,'Unknown')
df['product'] = df['product'].replace(np.nan,'Unknown')
df['brand'] = df['brand'].replace(np.nan,'Unknown')

# %%
df.isnull().sum()
# Out:
# index              0
# product            0
# category           0
# sub_category       0
# brand              0
# sale_price         0
# market_price       0
# type               0
# rating          8626
# description        0
# Discount           0
# dtype: int64

# %%
df['category'].unique()
# Out:
# array(['Beauty & Hygiene', 'Kitchen, Garden & Pets',
#        'Cleaning & Household', 'Gourmet & World Food',
#        'Foodgrains, Oil & Masala', 'Snacks & Branded Foods', 'Beverages',
#        'Bakery, Cakes & Dairy', 'Baby Care', 'Fruits & Vegetables',
#        'Eggs, Meat & Fish'], dtype=object)

# %%
# I want to fetch average rating based on category

mean_rating = df.groupby('category')['rating'].mean()
mean_rating
# Out:
# category
# Baby Care                   4.023790
# Bakery, Cakes & Dairy       3.911128
# Beauty & Hygiene            3.930655
# Beverages                   4.084858
# Cleaning & Household        3.956667
# Eggs, Meat & Fish                NaN
# Foodgrains, Oil & Masala    4.062198
# Fruits & Vegetables              NaN
# Gourmet & World Food        3.984410
# Kitchen, Garden & Pets      3.734715
# Snacks & Branded Foods      3.983313
# Name: rating, dtype: float64

# %%
df['rating'] = df['rating'].fillna(df.groupby('category')['rating'].transform('mean'))

# %%
df.isnull().sum()
# Out:
# index             0
# product           0
# category          0
# sub_category      0
# brand             0
# sale_price        0
# market_price      0
# type              0
# rating          907
# description       0
# Discount          0
# dtype: int64

# %%
df.fillna(0,inplace=True)

# %%
df.isnull().sum()
# Out:
# index           0
# product         0
# category        0
# sub_category    0
# brand           0
# sale_price      0
# market_price    0
# type            0
# rating          0
# description     0
# Discount        0
# dtype: int64

# %%
def label_rating(rating):
    if rating>=4:
        return "Good"

    elif rating>=3:
        return 'Average'

    elif rating>=0.1:
        return "Poor"

    else:
        return 'Unrated'

# %%
df['Target'] = df['rating'].apply(label_rating)

# %%
df
# Out:
#        index                                            product  \
# 0          1             Garlic Oil - Vegetarian Capsule 500 mg
# 1          2                              Water Bottle - Orange
# 2          3                     Brass Angle Deep - Plain, No.2
# 3          4  Cereal Flip Lid Container/Storage Jar - Assort...
# 4          5                 Creme Soft Soap - For Hands & Body
# ...      ...                                                ...
# 27550  27551         Wottagirl! Perfume Spray - Heaven, Classic
# 27551  27552                                           Rosemary
# 27552  27553                       Peri-Peri Sweet Potato Chips
# 27553  27554                          Green Tea - Pure Original
# 27554  27555                     United Dreams Go Far Deodorant
#
#                      category              sub_category  \
# 0            Beauty & Hygiene                 Hair Care
# 1      Kitchen, Garden & Pets     Storage & Accessories
# ...

# %%
df.drop(columns=['index'],inplace=True)

# %%
df.drop(columns=['description'],inplace=True)

# %%
df
# Out:
#                                                  product  \
# 0                 Garlic Oil - Vegetarian Capsule 500 mg
# 1                                  Water Bottle - Orange
# 2                         Brass Angle Deep - Plain, No.2
# 3      Cereal Flip Lid Container/Storage Jar - Assort...
# 4                     Creme Soft Soap - For Hands & Body
# ...                                                  ...
# 27550         Wottagirl! Perfume Spray - Heaven, Classic
# 27551                                           Rosemary
# 27552                       Peri-Peri Sweet Potato Chips
# 27553                          Green Tea - Pure Original
# 27554                     United Dreams Go Far Deodorant
#
#                      category              sub_category  \
# 0            Beauty & Hygiene                 Hair Care
# 1      Kitchen, Garden & Pets     Storage & Accessories
# 2        Cleaning & Household               Pooja Needs
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27555 entries, 0 to 27554
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   product       27555 non-null  object
#  1   category      27555 non-null  object
#  2   sub_category  27555 non-null  object
#  3   brand         27555 non-null  object
#  4   sale_price    27555 non-null  float64
#  5   market_price  27555 non-null  float64
#  6   type          27555 non-null  object
#  7   rating        27555 non-null  float64
#  8   Discount      27555 non-null  float64
#  9   Target        27555 non-null  object
# dtypes: float64(4), object(6)
# memory usage: 2.1+ MB

# %%
# RFE: Recursive Feature Elimination

from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
for x in df.columns:
    if df[x].dtype=='object':
        df[x] = le.fit_transform(df[x])

# %%
df
# Out:
#        product  category  sub_category  brand  sale_price  market_price  type  \
# 0         8277         2            49   1959      220.00         220.0   204
# 1        22936         9            86   1258      180.00         180.0   420
# 2         2957         4            73   2125      119.00         250.0   249
# 3         3573         4             9   1386      149.00         176.0   250
# 4         5476         2             8   1455      162.00         162.0    39
# ...        ...       ...           ...    ...         ...           ...   ...
# 27550    23384         2            41   1145      199.20         249.0   329
# 27551    18608         8            20   1672       67.50          75.0   215
# 27552    16244         8            82    675      200.00         200.0   286
# 27553     9120         3            87   2062      396.00         495.0   395
# 27554    22427         2            59   2158      214.53         390.0   271
#
#        rating  Discount  Target
# ...

# %%
from sklearn.feature_selection import RFE
from sklearn.ensemble import RandomForestClassifier

# %%
rf_model = RandomForestClassifier(random_state=42)

rfe = RFE(estimator=rf_model,n_features_to_select=5)

# %%
X = df.iloc[:,:-1]
y = df['Target']

# %%
X.drop(columns=['rating'],inplace=True)
X
# Out:
#        product  category  sub_category  brand  sale_price  market_price  type  \
# 0         8277         2            49   1959      220.00         220.0   204
# 1        22936         9            86   1258      180.00         180.0   420
# 2         2957         4            73   2125      119.00         250.0   249
# 3         3573         4             9   1386      149.00         176.0   250
# 4         5476         2             8   1455      162.00         162.0    39
# ...        ...       ...           ...    ...         ...           ...   ...
# 27550    23384         2            41   1145      199.20         249.0   329
# 27551    18608         8            20   1672       67.50          75.0   215
# 27552    16244         8            82    675      200.00         200.0   286
# 27553     9120         3            87   2062      396.00         495.0   395
# 27554    22427         2            59   2158      214.53         390.0   271
#
#        Discount
# ...

# %%
y
# Out:
# 0        1
# 1        2
# 2        0
# 3        0
# 4        1
#         ..
# 27550    0
# 27551    1
# 27552    0
# 27553    1
# 27554    1
# Name: Target, Length: 27555, dtype: int64

# %%
rfe.fit(X,y)
# Out:
# RFE(estimator=RandomForestClassifier(random_state=42), n_features_to_select=5)

# %%
rfe.support_  #This will give us the boolean output mentioning which columns to keep
# Out:
# array([ True, False, False,  True,  True,  True,  True, False])

# %%
li = list(X.columns[rfe.support_])
li
# Out:
# ['product', 'brand', 'sale_price', 'market_price', 'type']

# %%
X = X[li]
X
# Out:
#        product  brand  sale_price  market_price  type
# 0         8277   1959      220.00         220.0   204
# 1        22936   1258      180.00         180.0   420
# 2         2957   2125      119.00         250.0   249
# 3         3573   1386      149.00         176.0   250
# 4         5476   1455      162.00         162.0    39
# ...        ...    ...         ...           ...   ...
# 27550    23384   1145      199.20         249.0   329
# 27551    18608   1672       67.50          75.0   215
# 27552    16244    675      200.00         200.0   286
# 27553     9120   2062      396.00         495.0   395
# 27554    22427   2158      214.53         390.0   271
#
# [27555 rows x 5 columns]

# %%
y
# Out:
# 0        1
# 1        2
# 2        0
# 3        0
# 4        1
#         ..
# 27550    0
# 27551    1
# 27552    0
# 27553    1
# 27554    1
# Name: Target, Length: 27555, dtype: int64

# %%
x_train, x_test, y_train, y_test = train_test_split(X,y,train_size=0.8,random_state=0)

# %%
random_forest = RandomForestClassifier(random_state=42)
random_forest.fit(x_train,y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
from sklearn.metrics import *

# %%
y_pred = random_forest.predict(x_test)
accuracy_score(y_test,y_pred)
# Out:
# 0.683723462166576

# %%
df['Target'].value_counts()
# Out:
# Target
# 1    13202
# 0    12055
# 2     1391
# 3      907
# Name: count, dtype: int64

# %%
# Homework:
# Use Hyperparameter tuning and then build your random forest model
# GO for boosting algorithms and check the performance of the model
# Remove where we have 0 ratings and then use smote technique and build the model.
